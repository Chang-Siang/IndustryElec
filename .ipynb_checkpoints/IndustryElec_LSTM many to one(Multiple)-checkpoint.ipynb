# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Data/elec_merge_20160101_20190930.csv')
df.shape
# 20160101~20161231 [0~366]
# 20170101~20171231 [366~731]
# 20180101~20181231 [731~1095]
# 20190101~20190930 [1096~1368]
# Out:
# (1369, 8)

# %%
df.head()
# Out:
#            日期  尖峰負載(MW)  淨尖峰供電能力(MW)  備轉容量(MW)  備轉容量率(%)  工業用電(百萬度)  \
# 0  2016-01-01     23038      25366.0    2328.0     10.11    263.799
# 1  2016-01-02     23209      25179.0    1970.0      8.49    261.975
# 2  2016-01-03     23686      26219.0    2533.0     10.69    266.167
# 3  2016-01-04     27518      29528.0    2010.0      7.31    302.227
# 4  2016-01-05     27635      29735.0    2100.0      7.60    313.328
#
#    民生用電(百萬度)  isHoliday
# 0    189.300        1.0
# 1    187.991        1.0
# 2    190.999        1.0
# 3    216.875        0.0
# 4    224.841        0.0

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def rmse(y_pred, y_true):
    return np.sqrt(((y_pred - y_true) ** 2).mean())

# %% [markdown]
# ## 查看資料狀態

# %%
def plot_year(dates, value, title=None): 
    '''
    Args:
        dates: the 'date' column of the data
        value: the value you want to draw
        title: figure title
    Return:
        a plot
    '''
    plt.figure(figsize=(20,4))
    x_axis = pd.to_datetime(dates, format='%Y-%m-%d')
    plt.plot_date(x_axis, value, '-')
    plt.title(title)

# %%
# plt.figure(figsize=(16,4))
# x_axis = range(0, 365)
# plt.plot(x_axis, df[:366].head(365)['工業用電(百萬度)'], '-')
# plt.plot(x_axis, df[366:731].head(365)['工業用電(百萬度)'], '-')
# plt.plot(x_axis, df[731:1096].head(365)['工業用電(百萬度)'], '-')
# plt.title('Peak Loads 2016-2018')
# plt.legend(['2016', '2017', '2018'])
# plt.show()

# %% [markdown]
# ## 欄位篩選
# - 使用 2016年1月至2018年12月的資料進行訓練
# - 使用 2019年1月至2019年9月的資料進行測試
# - 此實驗僅保留用電量欄位

# %%
RawTrain = df[:1096]
# RawTrain = df[366:1096]
RawTest = df[1096:]

# %%
# 訓練資料擷取
training_set = pd.DataFrame(RawTrain[["工業用電(百萬度)", "isHoliday"]])
training_set.shape
# Out:
# (730, 2)

# %% [markdown]
# ## 資料前處理

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %% [markdown]
# ## 訓練資料

# %%
# 自定義變數
Timesteps = 30
OutputDay = 1

# %%
X_train = []   #預測點的前 60 天的資料
y_train = []   #預測點
for i in range(Timesteps, len(training_set)):  # 1258 是訓練集總數
    X_train.append(training_set_scaled[i-Timesteps:i])
    y_train.append(training_set_scaled[i:i+OutputDay, 0]) # 0 = 工業用電(百萬度)
# 轉成numpy array的格式，以利輸入 RNN    
X_train, y_train = np.array(X_train), np.array(y_train)  
print(X_train.shape)
print(y_train.shape)

# Reshape
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 2))
print(X_train.shape)
# Out:
# (700, 30, 2)
# (700,)

# %% [markdown]
# ## Model

# %%
# Import the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import SimpleRNN
from keras.layers import Dropout
from keras.optimizers import RMSprop
# Out:
# Using TensorFlow backend.

# %% [markdown]
# - units: 50
# - input_shape: 30
# - dropout: 0.2

# %%
# Initialising the LSTM
Model = Sequential()
# Adding the first LSTM layer and some Dropout regularisation
Model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
Model.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
Model.add(LSTM(units = 50, return_sequences = True))
Model.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
Model.add(LSTM(units = 50, return_sequences = True))
Model.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
Model.add(LSTM(units = 50))
Model.add(Dropout(0.2))

# Adding the output layer
Model.add(Dense(units = 1))

Model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 30, 50)            10400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 50)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 30, 50)            20200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 50)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 30, 50)            20200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 30, 50)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16
epochs = 100

# initialize optimizer
# optimizer = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
# Model.compile(loss='mean_squared_error', optimizer=RMSprop(lr=0.0001), metrics=['mape'])
Model.compile(optimizer = 'adam', loss = 'mean_squared_error')

Model.fit(X_train, y_train,
          batch_size = batch_size,
          epochs = epochs,
          verbose=1,
          validation_split=0.1)
# Out:
# Train on 630 samples, validate on 70 samples
# Epoch 1/100
# 630/630 [==============================] - 15s 24ms/step - loss: 0.0822 - val_loss: 0.0162
# Epoch 2/100
# 630/630 [==============================] - 9s 14ms/step - loss: 0.0281 - val_loss: 0.0164
# Epoch 3/100
# 630/630 [==============================] - 8s 13ms/step - loss: 0.0261 - val_loss: 0.0164
# Epoch 4/100
# 630/630 [==============================] - 9s 14ms/step - loss: 0.0282 - val_loss: 0.0202
# Epoch 5/100
# 630/630 [==============================] - 9s 14ms/step - loss: 0.0262 - val_loss: 0.0165
# Epoch 6/100
# 630/630 [==============================] - 9s 14ms/step - loss: 0.0262 - val_loss: 0.0246
# Epoch 7/100
# 630/630 [==============================] - 8s 13ms/step - loss: 0.0258 - val_loss: 0.0165
# Epoch 8/100
# 630/630 [==============================] - 8s 13ms/step - loss: 0.0267 - val_loss: 0.0223
# Epoch 9/100
# 630/630 [==============================] - 8s 13ms/step - loss: 0.0258 - val_loss: 0.0168
# Epoch 10/100
#  32/630 [>.............................] - ETA: 8s - loss: 0.0225

# %% [markdown]
# ---
# # Time

# %%
t = 5

# %% [markdown]
# ---
# ## Load Model

# %%
# # load
# from keras.models import load_model
# Model = load_model('Model/industryElec_RNN(30to1)_model_0' + str(t) + '.h5')

# %% [markdown]
# ---
# ## Self-Prediction

# %%
self_true = training_set.values[Timesteps:,]
self_predict = Model.predict(X_train)
self_prediction = sc.inverse_transform(self_predict)

# %%
# RMSE
print("RMSE: ", rmse(self_true, self_prediction))
# MAPE
print("MAPE: ", mean_absolute_percentage_error(self_true, self_prediction))
# Out:
# RMSE:  23.80762605076322
# MAPE:  5.999310165266992

# %%
# Visualising the model
plt.figure(figsize=(30, 10))
plt.plot(self_true, color = 'red', label = 'Real')
plt.plot(self_prediction, color = 'blue', label = 'Prediction')
plt.title('Industry Elec Prediction(LSTM-2)(Self) t1')
plt.xlabel('Time')
plt.ylabel('kW')
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## Test-Prediction

# %%
# 自定義變數
# Pre_step = 1
# Pre_step = 4
Pre_step = 39

# %%
# 真實值擷取
pre_time = 7 * Pre_step
test_set = pd.DataFrame(RawTest[["工業用電(百萬度)"]])
test_set = test_set[:pre_time]
# 真實資料
real_elec = test_set.values

# %%
dataset_total = pd.DataFrame(df[["工業用電(百萬度)"]])
dataset_total = dataset_total[:1096 + pre_time]

inputs = dataset_total[len(dataset_total) - len(test_set) - 30:].values
inputs = inputs.reshape(-1, 1)
 # Feature Scaling
inputs = sc.transform(inputs)

# %%
X_test = []
for i in range(30, 30 + pre_time):  
    # timesteps 30；60 = 先前的 30天資料 + 2019年的 30天資料
    X_test.append(inputs[i-30:i, 0])
X_test = np.array(X_test)
# Reshape 成 3-dimension
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 2))

# %%
# 執行預測
predicted_elec = Model.predict(X_test)
# 尺度還原
predicted_elec = sc.inverse_transform(predicted_elec)

# %% [markdown]
# ## 計算評估指標

# %%
# RMSE
print("RMSE: ", rmse(real_elec, predicted_elec))
# MAPE
print("MAPE: ", mean_absolute_percentage_error(real_elec, predicted_elec))
# Out:
# RMSE:  22.76310466212967
# MAPE:  5.819416878678236

# %%
# Visualising the results
plt.plot(real_elec, color = 'red', label = 'Real')
plt.plot(predicted_elec, color = 'blue', label = 'Predicted')
plt.title('Industry Elec Prediction(LSTM) t' + str(t))
plt.xlabel('Time')
plt.ylabel('kW')
plt.legend()
plt.show()

# %% [markdown]
# ## Save Model

# %%
# import h5py
# Model.save('Model/industryElec_LSTM(30to1)_model_0' + str(t) + '.h5')
