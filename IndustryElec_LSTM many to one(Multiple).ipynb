# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Data/elec_merge_20160101_20190930.csv')
df.shape
# 20160101~20161231 [0~366]
# 20170101~20171231 [366~731]
# 20180101~20181231 [731~1095]
# 20190101~20190930 [1096~1368]
# Out:
# (1461, 10)

# %%
df.head()
# Out:
#            日期  尖峰負載(MW)  淨尖峰供電能力(MW)  備轉容量(MW)  備轉容量率(%)  工業用電(百萬度)  \
# 0  2016-01-01   23038.0      25366.0    2328.0     10.11    263.799
# 1  2016-01-02   23209.0      25179.0    1970.0      8.49    261.975
# 2  2016-01-03   23686.0      26219.0    2533.0     10.69    266.167
# 3  2016-01-04   27518.0      29528.0    2010.0      7.31    302.227
# 4  2016-01-05   27635.0      29735.0    2100.0      7.60    313.328
#
#    民生用電(百萬度)  isHoliday  isHoliday(Next7)  Week
# 0    189.300        1.0               0.0   4.0
# 1    187.991        1.0               1.0   5.0
# 2    190.999        1.0               1.0   6.0
# 3    216.875        0.0               0.0   0.0
# 4    224.841        0.0               0.0   1.0

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def rmse(y_pred, y_true):
    return np.sqrt(((y_pred - y_true) ** 2).mean())

# %% [markdown]
# ## 查看資料狀態

# %%
def plot_year(dates, value, title=None): 
    '''
    Args:
        dates: the 'date' column of the data
        value: the value you want to draw
        title: figure title
    Return:
        a plot
    '''
    plt.figure(figsize=(20,4))
    x_axis = pd.to_datetime(dates, format='%Y-%m-%d')
    plt.plot_date(x_axis, value, '-')
    plt.title(title)

# %%
plt.figure(figsize=(12,5))
x_axis = range(0, 365)
plt.plot(x_axis, df[:366].head(365)['工業用電(百萬度)'], '-')
# plt.plot(x_axis, df[366:731].head(365)['工業用電(百萬度)'], '-')
plt.plot(x_axis, df[731:1096].head(365)['工業用電(百萬度)'], '-')
# plt.plot(x_axis, df[1096:].head(365)['工業用電(百萬度)'], '-')
plt.title('Loads 2017-2018')
plt.legend(['2018', '2019'])
plt.show()

# %% [markdown]
# ## 欄位篩選
# - 使用 2016年1月至2018年12月的資料進行訓練
# - 使用 2019年1月至2019年9月的資料進行測試
# - 此實驗僅保留用電量欄位

# %%
RawTrain = df[:1096]
# RawTrain = df[366:1096]
RawTest = df[1096:]

# %%
features_select = ["工業用電(百萬度)", "isHoliday", "尖峰負載(MW)"]
# features_select = ["工業用電(百萬度)"]

# %%
# 訓練資料擷取
training_set = pd.DataFrame(RawTrain[features_select])
training_set.shape
# Out:
# (1096, 3)

# %% [markdown]
# ## 資料前處理

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Out:
# C:\Users\siang\Anaconda3\envs\tensorflow-gpu\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %% [markdown]
# ## 訓練資料

# %%
# 自定義變數
Timesteps = 30
OutputDay = 1

# %%
X_train, y_train = [], []

for i in range(Timesteps, len(training_set)):  # 1258 是訓練集總數
    X_train.append(training_set_scaled[i-Timesteps:i])
    y_train.append(training_set_scaled[i:i+OutputDay, 0]) # 0 = 工業用電(百萬度)
    
# 轉成numpy array的格式，以利輸入 RNN    
X_train, y_train = np.array(X_train), np.array(y_train)  
print(X_train.shape)
print(y_train.shape)

# Reshape
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
print(X_train.shape)
# Out:
# (1066, 30, 3)
# (1066, 1)
# (1066, 30, 3)

# %% [markdown]
# ## Model

# %%
# Import the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, CuDNNLSTM
from keras.layers import SimpleRNN
from keras.layers import Dropout
from keras.optimizers import RMSprop

# %% [markdown]
# ### CuDNNLSTM

# %%
# Initialising the CuDNNLSTM
model = Sequential()
# Adding the first LSTM layer and some Dropout regularisation
model.add(CuDNNLSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))

for i in range(2):
    # Adding a second LSTM layer and some Dropout regularisation
    model.add(CuDNNLSTM(units = 50, return_sequences = True))
    model.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
model.add(CuDNNLSTM(units = 50))
model.add(Dropout(0.2))

# Adding the output layer
model.add(Dense(units = 1))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cu_dnnlstm_29 (CuDNNLSTM)    (None, 30, 50)            11000
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 30, 50)            0
# _________________________________________________________________
# cu_dnnlstm_30 (CuDNNLSTM)    (None, 30, 50)            20400
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 30, 50)            0
# _________________________________________________________________
# cu_dnnlstm_31 (CuDNNLSTM)    (None, 30, 50)            20400
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 30, 50)            0
# _________________________________________________________________
# cu_dnnlstm_32 (CuDNNLSTM)    (None, 50)                20400
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 72,251
# Trainable params: 72,251
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### LSTM

# %%
# # Initialising the LSTM
# model = Sequential()
# # Adding the first LSTM layer and some Dropout regularisation
# model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
# model.add(Dropout(0.2))

# for i in range(2):
#     # Adding a second LSTM layer and some Dropout regularisation
#     model.add(LSTM(units = 50, return_sequences = True))
#     model.add(Dropout(0.2))

# # Adding a fourth LSTM layer and some Dropout regularisation
# model.add(LSTM(units = 50))
# model.add(Dropout(0.2))

# # Adding the output layer
# model.add(Dense(units = 1))

# model.summary()

# %%
batch_size = 16
epochs = 100

# initialize optimizer
# optimizer = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
# Model.compile(loss='mean_squared_error', optimizer=RMSprop(lr=0.0001), metrics=['mape'])
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

model.fit(X_train, y_train,
          batch_size = batch_size,
          epochs = epochs,
          verbose=1,
          validation_split=0.1)
# Out:
# Train on 959 samples, validate on 107 samples
# Epoch 1/100
# 959/959 [==============================] - 2s 2ms/step - loss: 0.0438 - val_loss: 0.0145
# Epoch 2/100
# 959/959 [==============================] - 1s 941us/step - loss: 0.0228 - val_loss: 0.0191
# Epoch 3/100
# 959/959 [==============================] - 1s 962us/step - loss: 0.0229 - val_loss: 0.0157
# Epoch 4/100
# 959/959 [==============================] - 1s 946us/step - loss: 0.0227 - val_loss: 0.0140
# Epoch 5/100
# 959/959 [==============================] - 1s 938us/step - loss: 0.0222 - val_loss: 0.0136
# Epoch 6/100
# 959/959 [==============================] - 1s 938us/step - loss: 0.0229 - val_loss: 0.0131
# Epoch 7/100
# 959/959 [==============================] - 1s 923us/step - loss: 0.0216 - val_loss: 0.0158
# Epoch 8/100
# 959/959 [==============================] - 1s 923us/step - loss: 0.0203 - val_loss: 0.0182
# Epoch 9/100
# 959/959 [==============================] - 1s 929us/step - loss: 0.0212 - val_loss: 0.0114
# Epoch 10/100
# 959/959 [==============================] - 1s 962us/step - loss: 0.0189 - val_loss: 0.0118
# Epoch 11/100
# 959/959 [==============================] - 1s 943us/step - loss: 0.0186 - val_loss: 0.0122
# Epoch 12/100
# 959/959 [==============================] - 1s 963us/step - loss: 0.0199 - val_loss: 0.0117
# Epoch 13/100
# 959/959 [==============================] - 1s 944us/step - loss: 0.0189 - val_loss: 0.0163
# Epoch 14/100
# 959/959 [==============================] - 1s 931us/step - loss: 0.0192 - val_loss: 0.0128
# Epoch 15/100
# 959/959 [==============================] - 1s 923us/step - loss: 0.0183 - val_loss: 0.0115
# Epoch 16/100
# 959/959 [==============================] - 1s 950us/step - loss: 0.0188 - val_loss: 0.0162
# Epoch 17/100
# 959/959 [==============================] - 1s 954us/step - loss: 0.0168 - val_loss: 0.0142
# Epoch 18/100
# 959/959 [==============================] - 1s 933us/step - loss: 0.0182 - val_loss: 0.0117
# Epoch 19/100
# 959/959 [==============================] - 1s 938us/step - loss: 0.0170 - val_loss: 0.0126
# Epoch 20/100
# 959/959 [==============================] - 1s 932us/step - loss: 0.0173 - val_loss: 0.0110
# Epoch 21/100
# 959/959 [==============================] - 1s 937us/step - loss: 0.0178 - val_loss: 0.0120
# Epoch 22/100
# 959/959 [==============================] - 1s 966us/step - loss: 0.0159 - val_loss: 0.0107
# Epoch 23/100
# 959/959 [==============================] - 1s 917us/step - loss: 0.0171 - val_loss: 0.0114
# Epoch 24/100
# 959/959 [==============================] - 1s 918us/step - loss: 0.0159 - val_loss: 0.0102
# Epoch 25/100
# 959/959 [==============================] - 1s 948us/step - loss: 0.0160 - val_loss: 0.0105
# Epoch 26/100
# 959/959 [==============================] - 1s 946us/step - loss: 0.0146 - val_loss: 0.0106
# Epoch 27/100
# 959/959 [==============================] - 1s 960us/step - loss: 0.0136 - val_loss: 0.0123
# Epoch 28/100
# 959/959 [==============================] - 1s 955us/step - loss: 0.0146 - val_loss: 0.0091
# Epoch 29/100
# 959/959 [==============================] - 1s 934us/step - loss: 0.0127 - val_loss: 0.0113
# Epoch 30/100
# 959/959 [==============================] - 1s 908us/step - loss: 0.0128 - val_loss: 0.0083
# Epoch 31/100
# 959/959 [==============================] - 1s 939us/step - loss: 0.0142 - val_loss: 0.0081
# Epoch 32/100
# 959/959 [==============================] - 1s 924us/step - loss: 0.0117 - val_loss: 0.0087
# Epoch 33/100
# 959/959 [==============================] - 1s 974us/step - loss: 0.0117 - val_loss: 0.0094
# Epoch 34/100
# 959/959 [==============================] - 1s 941us/step - loss: 0.0113 - val_loss: 0.0080
# Epoch 35/100
# 959/959 [==============================] - 1s 950us/step - loss: 0.0113 - val_loss: 0.0073
# Epoch 36/100
# 959/959 [==============================] - 1s 950us/step - loss: 0.0103 - val_loss: 0.0101
# Epoch 37/100
# 959/959 [==============================] - 1s 929us/step - loss: 0.0101 - val_loss: 0.0059
# Epoch 38/100
# 959/959 [==============================] - 1s 967us/step - loss: 0.0106 - val_loss: 0.0077
# Epoch 39/100
# 959/959 [==============================] - 1s 942us/step - loss: 0.0101 - val_loss: 0.0074
# Epoch 40/100
# 959/959 [==============================] - 1s 943us/step - loss: 0.0104 - val_loss: 0.0069
# Epoch 41/100
# 959/959 [==============================] - 1s 941us/step - loss: 0.0098 - val_loss: 0.0065
# Epoch 42/100
# 959/959 [==============================] - 1s 924us/step - loss: 0.0089 - val_loss: 0.0056
# Epoch 43/100
# 959/959 [==============================] - 1s 927us/step - loss: 0.0087 - val_loss: 0.0055
# Epoch 44/100
# 959/959 [==============================] - 1s 953us/step - loss: 0.0088 - val_loss: 0.0077
# Epoch 45/100
# 959/959 [==============================] - 1s 945us/step - loss: 0.0087 - val_loss: 0.0053
# Epoch 46/100
# 959/959 [==============================] - 1s 945us/step - loss: 0.0085 - val_loss: 0.0052
# Epoch 47/100
# 959/959 [==============================] - 1s 943us/step - loss: 0.0077 - val_loss: 0.0051
# Epoch 48/100
# 959/959 [==============================] - 1s 962us/step - loss: 0.0078 - val_loss: 0.0043
# Epoch 49/100
# 959/959 [==============================] - 1s 955us/step - loss: 0.0073 - val_loss: 0.0043
# Epoch 50/100
# 959/959 [==============================] - 1s 943us/step - loss: 0.0074 - val_loss: 0.0048
# Epoch 51/100
# 959/959 [==============================] - 1s 955us/step - loss: 0.0070 - val_loss: 0.0044
# Epoch 52/100
# 959/959 [==============================] - 1s 941us/step - loss: 0.0073 - val_loss: 0.0042
# Epoch 53/100
# 959/959 [==============================] - 1s 911us/step - loss: 0.0068 - val_loss: 0.0050
# Epoch 54/100
# 959/959 [==============================] - 1s 926us/step - loss: 0.0071 - val_loss: 0.0055
# Epoch 55/100
# 959/959 [==============================] - 1s 924us/step - loss: 0.0064 - val_loss: 0.0039
# Epoch 56/100
# 959/959 [==============================] - 1s 957us/step - loss: 0.0067 - val_loss: 0.0048
# Epoch 57/100
# 959/959 [==============================] - 1s 930us/step - loss: 0.0063 - val_loss: 0.0039
# Epoch 58/100
# 959/959 [==============================] - 1s 975us/step - loss: 0.0063 - val_loss: 0.0040
# Epoch 59/100
# 959/959 [==============================] - 1s 941us/step - loss: 0.0065 - val_loss: 0.0036
# Epoch 60/100
# 959/959 [==============================] - 1s 963us/step - loss: 0.0065 - val_loss: 0.0040
# Epoch 61/100
# 959/959 [==============================] - 1s 933us/step - loss: 0.0061 - val_loss: 0.0041
# Epoch 62/100
# 959/959 [==============================] - 1s 942us/step - loss: 0.0057 - val_loss: 0.0038
# Epoch 63/100
# 959/959 [==============================] - 1s 907us/step - loss: 0.0056 - val_loss: 0.0033
# Epoch 64/100
# 959/959 [==============================] - 1s 946us/step - loss: 0.0061 - val_loss: 0.0037
# Epoch 65/100
# 959/959 [==============================] - 1s 947us/step - loss: 0.0062 - val_loss: 0.0059
# Epoch 66/100
# 959/959 [==============================] - 1s 939us/step - loss: 0.0059 - val_loss: 0.0033
# Epoch 67/100
# 959/959 [==============================] - 1s 949us/step - loss: 0.0054 - val_loss: 0.0046
# Epoch 68/100
# 959/959 [==============================] - 1s 963us/step - loss: 0.0061 - val_loss: 0.0049
# Epoch 69/100
# 959/959 [==============================] - 1s 968us/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 70/100
# 959/959 [==============================] - 1s 975us/step - loss: 0.0059 - val_loss: 0.0031
# Epoch 71/100
# 959/959 [==============================] - 1s 919us/step - loss: 0.0052 - val_loss: 0.0036
# Epoch 72/100
# 959/959 [==============================] - 1s 935us/step - loss: 0.0058 - val_loss: 0.0036
# Epoch 73/100
# 959/959 [==============================] - 1s 968us/step - loss: 0.0054 - val_loss: 0.0034
# Epoch 74/100
# 959/959 [==============================] - 1s 908us/step - loss: 0.0055 - val_loss: 0.0036
# Epoch 75/100
# 959/959 [==============================] - 1s 952us/step - loss: 0.0051 - val_loss: 0.0031
# Epoch 76/100
# 959/959 [==============================] - 1s 955us/step - loss: 0.0050 - val_loss: 0.0031
# Epoch 77/100
# 959/959 [==============================] - 1s 917us/step - loss: 0.0053 - val_loss: 0.0030
# Epoch 78/100
# 959/959 [==============================] - 1s 961us/step - loss: 0.0046 - val_loss: 0.0031
# Epoch 79/100
# 959/959 [==============================] - 1s 939us/step - loss: 0.0053 - val_loss: 0.0029
# Epoch 80/100
# 959/959 [==============================] - 1s 923us/step - loss: 0.0053 - val_loss: 0.0030
# Epoch 81/100
# 959/959 [==============================] - 1s 934us/step - loss: 0.0048 - val_loss: 0.0029
# Epoch 82/100
# 959/959 [==============================] - 1s 930us/step - loss: 0.0049 - val_loss: 0.0032
# Epoch 83/100
# 959/959 [==============================] - 1s 924us/step - loss: 0.0046 - val_loss: 0.0031
# Epoch 84/100
# 959/959 [==============================] - 1s 942us/step - loss: 0.0050 - val_loss: 0.0039
# Epoch 85/100
# 959/959 [==============================] - 1s 946us/step - loss: 0.0050 - val_loss: 0.0037
# Epoch 86/100
# 959/959 [==============================] - 1s 957us/step - loss: 0.0047 - val_loss: 0.0028
# Epoch 87/100
# 959/959 [==============================] - 1s 961us/step - loss: 0.0044 - val_loss: 0.0029
# Epoch 88/100
# 959/959 [==============================] - 1s 951us/step - loss: 0.0044 - val_loss: 0.0028
# Epoch 89/100
# 959/959 [==============================] - 1s 936us/step - loss: 0.0046 - val_loss: 0.0035
# Epoch 90/100
# 959/959 [==============================] - 1s 926us/step - loss: 0.0042 - val_loss: 0.0028
# Epoch 91/100
# 959/959 [==============================] - 1s 937us/step - loss: 0.0044 - val_loss: 0.0028
# Epoch 92/100
# 959/959 [==============================] - 1s 922us/step - loss: 0.0045 - val_loss: 0.0026
# Epoch 93/100
# 959/959 [==============================] - 1s 921us/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 94/100
# 959/959 [==============================] - 1s 932us/step - loss: 0.0042 - val_loss: 0.0031
# Epoch 95/100
# 959/959 [==============================] - 1s 941us/step - loss: 0.0044 - val_loss: 0.0031
# Epoch 96/100
# 959/959 [==============================] - 1s 902us/step - loss: 0.0043 - val_loss: 0.0032
# Epoch 97/100
# 959/959 [==============================] - 1s 943us/step - loss: 0.0042 - val_loss: 0.0033
# Epoch 98/100
# 959/959 [==============================] - 1s 928us/step - loss: 0.0043 - val_loss: 0.0036
# Epoch 99/100
# 959/959 [==============================] - 1s 938us/step - loss: 0.0042 - val_loss: 0.0025
# Epoch 100/100
# 959/959 [==============================] - 1s 918us/step - loss: 0.0039 - val_loss: 0.0026

# %% [markdown]
# ---
# # Time

# %%
t = 1

# %% [markdown]
# ---
# ## Load Model

# %%
# # load
# from keras.models import load_model
# model = load_model('Model/industryElec_RNN(30to1)_model_0' + str(t) + '.h5')

# %% [markdown]
# ---
# ## Self-Prediction

# %%
self_true = pd.DataFrame(training_set[["工業用電(百萬度)"]]).values[Timesteps:,]
self_predict = model.predict(X_train)
# self_prediction = sc.inverse_transform(self_predict)
self_prediction = self_predict * (sc.data_max_[0]-sc.data_min_[0]) + sc.data_min_[0]

# %%
# RMSE
print("RMSE: ", rmse(self_true, self_prediction))
# MAPE
print("MAPE: ", mean_absolute_percentage_error(self_true, self_prediction))
# Out:
# RMSE:  9.536787089610712
# MAPE:  2.0589806578030325

# %%
# Visualising the model
plt.figure(figsize=(30, 10))
plt.plot(self_true, color = 'red', label = 'Real')
plt.plot(self_prediction, color = 'blue', label = 'Prediction')
plt.title('Industry Elec Prediction(LSTM-2)(Self) t' + str(t))
plt.xlabel('Time')
plt.ylabel('kW')
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## Test-Prediction

# %%
# 自定義變數
# Pre_step = 1
# Pre_step = 4
Pre_step = 39

# %%
# 真實值擷取
pre_time = 7 * Pre_step
test_set = pd.DataFrame(RawTest[["工業用電(百萬度)"]])
test_set = test_set[:pre_time]
# 真實資料
real_elec = test_set.values

# %%
dataset_total = pd.DataFrame(df[features_select])
dataset_total = dataset_total[:len(training_set) + pre_time]

inputs = dataset_total[len(dataset_total) - len(test_set) - 30:].values
inputs = inputs.reshape(-1, dataset_total.shape[1])
 # Feature Scaling
inputs = sc.transform(inputs)

# %%
X_test = []
for i in range(30, 30 + pre_time):  
    # timesteps 30；60 = 先前的 30天資料 + 2019年的 30天資料
    X_test.append(inputs[i-30:i])
X_test = np.array(X_test)
# Reshape 成 3-dimension
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
# 執行預測
predicted_elec = model.predict(X_test)
# 尺度還原
predicted_elec = predicted_elec * (sc.data_max_[0]-sc.data_min_[0]) + sc.data_min_[0]

# %% [markdown]
# ## 計算評估指標

# %%
# RMSE
print("RMSE: ", rmse(real_elec, predicted_elec))
# MAPE
print("MAPE: ", mean_absolute_percentage_error(real_elec, predicted_elec))
# Out:
# RMSE:  11.793756415281786
# MAPE:  2.6367626867050324

# %%
# Visualising the results
plt.plot(real_elec, color = 'red', label = 'Real')
plt.plot(predicted_elec, color = 'blue', label = 'Predicted')
plt.title('Industry Elec Prediction(LSTM) t' + str(t))
plt.xlabel('Time')
plt.ylabel('kW')
plt.legend()
plt.show()

# %% [markdown]
# ## Save Model

# %%
# import h5py
# Model.save('Model/industryElec_LSTM(30to1)_model_0' + str(t) + '.h5')
